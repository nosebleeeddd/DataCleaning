# %%
import pandas as pd

# %% [markdown]
# # 1a.LOAD CSV DATA

# %%
data = pd.read_csv("HR-Employee-Attrition.csv")

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # 1b.CHECK FOR NaN VALUES

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # 1c.START TRANSFORMING TASKS

# %%
''' TASKS
Deleting redundant columns.
Renaming the columns.
Dropping duplicates.
Cleaning individual columns.
Remove the NaN values from the dataset
Check for some more Transformations
'''

# %% [markdown]
# ## 1.DELETE REDUNDANT COLUMNS

# %%
# create filters for columns kept and dropped
columns_to_keep = ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'HourlyRate', 'JobRole', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager' ]
columns_to_drop = ['EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance']

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# CHECK THE DATA TABLE
data.head(3).iloc[:,13:22]

# %%
# WE KEEP 13
len(columns_to_keep)
# Out:
# 13

# %%
# WE DROP 22
len(columns_to_drop)
# Out:
# 22

# %%
# 35 TOTAL COLUMNS
data.shape
# Out:
# (1470, 35)

# %% [markdown]
# ## 1st method

# %%
# FILTERING THE DATA WITH OUR COLUMNS
#data[['Age', 'Attrition', 'BusinessTravel']] or: data[columns_to_keep]
new_data = data[columns_to_keep]

# %% [markdown]
# ## 2nd method

# %%
# INPLACE sets the new dataframe or you can reassign to a variable
#data.drop(columns = ["Age", "Attrition"], inplace = True) or:
#data_new = data.drop(columns = ["Age", "Attrition"]
#data_new_2 = data.drop(columns = columns_to_drop)   CHECKS FOR CHANGED TABLE
data.drop(columns = columns_to_drop,inplace= True)   # sets dataframe

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education  HourlyRate                    JobRole  \
# ...

# %%
''' TASKS
Deleting redundant columns.              x
Renaming the columns.                    
Dropping duplicates.                     
Cleaning individual columns.             
Remove the NaN values from the dataset   
Check for some more Transformations      
'''

# %% [markdown]
# ## 2.RENAMING THE COLUMNS

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'HourlyRate', 'JobRole',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# CHANGE COLUMN NAME MANUALLY
data.rename(columns = {"DistanceFromHome": "DistanceHome"},inplace = True)

# %%
data.rename(columns = {"DailyRate": "DailyWage", 'HourlyRate': 'HourlyWage'})
# Out:
#       Age Attrition     BusinessTravel  DailyWage              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceHome  Education  HourlyWage                    JobRole  \
# ...

# %%
''' TASKS
Deleting redundant columns.              x
Renaming the columns.                    x
Dropping duplicates.                     
Cleaning individual columns.             
Remove the NaN values from the dataset   
Check for some more Transformations      
'''

# %% [markdown]
# ## 3.DROPPING DUPLICATES

# %%
# CHECK FOR ANY DUPLICATES
#data.duplicated()
#data.duplicated().head(20
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# WE HAVE NO DUPLICATES BUT IF WE DID DO
data.drop_duplicates(inplace=True)

# %%
''' TASKS
Deleting redundant columns.              x
Renaming the columns.                    x
Dropping duplicates.                     x
Cleaning individual columns.             
Remove the NaN values from the dataset   
Check for some more Transformations      
'''

# %% [markdown]
# ## 4.CLEAN INDIVIDUAL COLUMNS

# %%
data.shape
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceHome  Education  HourlyRate                    JobRole  \
# ...

# %%
# EXAMPLE METHODS
# FILTER FOR ANYONE WITH <= YearsAtCompany
data[data["YearsAtCompany"] <= 8].shape
# Out:
# (1022, 13)

# %%
# FILTER FOR YES IN ATTRITION COLUMN
data[data["Attrition"] == "Yes"]["Attrition"].unique()
# Out:
# array(['Yes'], dtype=object)

# %%
### MAKE A COPY SO WE HAVE MODIFIED DATA N OG DATA
modify_data = data.copy()

# %%
modify_data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceHome  Education  HourlyRate                    JobRole  \
# ...

# %%
# REPLACE UNDERSCORES

# check type first
type(modify_data["BusinessTravel"][1])

# now we clean column
modify_data["BusinessTravel"].str.replace("_", " ")
# Out:
# 0           Travel Rarely
# 1       Travel Frequently
# 2           Travel Rarely
# 3       Travel Frequently
# 4           Travel Rarely
#               ...
# 1465    Travel Frequently
# 1466        Travel Rarely
# 1467        Travel Rarely
# 1468    Travel Frequently
# 1469        Travel Rarely
# Name: BusinessTravel, Length: 1470, dtype: object

# %%
# SET CHANGES TO MODIFY_DATA
modify_data["BusinessTravel"] = modify_data["BusinessTravel"].str.replace("_"," ")

# %%
modify_data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel Rarely       1102                   Sales
# 1      49        No  Travel Frequently        279  Research & Development
# 2      37       Yes      Travel Rarely       1373  Research & Development
# 3      33        No  Travel Frequently       1392  Research & Development
# 4      27        No      Travel Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel Frequently        884  Research & Development
# 1466   39        No      Travel Rarely        613  Research & Development
# 1467   27        No      Travel Rarely        155  Research & Development
# 1468   49        No  Travel Frequently       1023                   Sales
# 1469   34        No      Travel Rarely        628  Research & Development
#
#       DistanceHome  Education  HourlyRate                    JobRole  \
# ...

# %%
''' TASKS
Deleting redundant columns.              x
Renaming the columns.                    x
Dropping duplicates.                     x
Cleaning individual columns.             x
Remove the NaN values from the dataset   
Check for some more Transformations      
'''

# %% [markdown]
# ## 5.REMOVE NaN VALUES

# %%
# CHECK FOR NAN VALUES
modify_data.isna()        # booleans
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  DistanceHome  \
# 0     False      False           False      False       False         False
# 1     False      False           False      False       False         False
# 2     False      False           False      False       False         False
# 3     False      False           False      False       False         False
# 4     False      False           False      False       False         False
# ...     ...        ...             ...        ...         ...           ...
# 1465  False      False           False      False       False         False
# 1466  False      False           False      False       False         False
# 1467  False      False           False      False       False         False
# 1468  False      False           False      False       False         False
# 1469  False      False           False      False       False         False
#
# ...

# %%
# CHECK FOR NAN VALUES
modify_data.isna().sum()              # NAN count column wise
#modify_data.isna().sum().tail(3)     # works too
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# DailyRate                  0
# Department                 0
# DistanceHome               0
# Education                  0
# HourlyRate                 0
# JobRole                    0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
# WE HAVE NO NAN VALUES BUT DO THIS IF SO
data.dropna(inplace = True)
data = data.dropna()

# %%
''' TASKS
Deleting redundant columns.              x
Renaming the columns.                    x
Dropping duplicates.                     x
Cleaning individual columns.             x
Remove the NaN values from the dataset   x
Check for some more Transformations      
'''

# %% [markdown]
# ## 6.CHECK FOR MORE TRANSFORMATIONS

# %%
modify_data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel Rarely       1102                   Sales
# 1      49        No  Travel Frequently        279  Research & Development
# 2      37       Yes      Travel Rarely       1373  Research & Development
# 3      33        No  Travel Frequently       1392  Research & Development
# 4      27        No      Travel Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel Frequently        884  Research & Development
# 1466   39        No      Travel Rarely        613  Research & Development
# 1467   27        No      Travel Rarely        155  Research & Development
# 1468   49        No  Travel Frequently       1023                   Sales
# 1469   34        No      Travel Rarely        628  Research & Development
#
#       DistanceHome  Education  HourlyRate                    JobRole  \
# ...

# %%
# CHANGE ATTITION TO '1 Yes' or '2 No' with lambda
#modify_data["Attrition"].apply(lambda x: 1 if x == "Yes" else 0)

# %%
# APPLIES THE CHANGES
modify_data["Attrition"] = modify_data["Attrition"].apply(lambda x: 1 if x == "Yes" else 0)

# %%
modify_data
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel Rarely       1102                   Sales
# 1      49          0  Travel Frequently        279  Research & Development
# 2      37          1      Travel Rarely       1373  Research & Development
# 3      33          0  Travel Frequently       1392  Research & Development
# 4      27          0      Travel Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel Frequently        884  Research & Development
# 1466   39          0      Travel Rarely        613  Research & Development
# 1467   27          0      Travel Rarely        155  Research & Development
# 1468   49          0  Travel Frequently       1023                   Sales
# 1469   34          0      Travel Rarely        628  Research & Development
#
# ...

# %%
# CHECK WE CHANGED THE TYPE
type(modify_data["Attrition"][1])
# Out:
# numpy.int64

# %%
''' TASKS
Deleting redundant columns.              x
Renaming the columns.                    x
Dropping duplicates.                     x
Cleaning individual columns.             x
Remove the NaN values from the dataset   x
Check for some more Transformations      x
'''

# %% [markdown]
# ## EXPORTING DATA

# %%
modify_data

# %% [markdown]
# ### CSV

# %%
# INDEX SETS A # COLUMN INDEX ON THE LEFT OF ROWS
modify_data.to_csv("Cleaned_Data.csv",index = False)

# %%
# READS THE NEWLY CLEANED FILE
pd.read_csv("Cleaned_Data.csv").head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel Rarely       1102                   Sales
# 1   49          0  Travel Frequently        279  Research & Development
# 2   37          1      Travel Rarely       1373  Research & Development
# 3   33          0  Travel Frequently       1392  Research & Development
# 4   27          0      Travel Rarely        591  Research & Development
#
#    DistanceHome  Education  HourlyRate                JobRole  YearsAtCompany  \
# 0             1          2          94        Sales Executive               6
# 1             8          1          61     Research Scientist              10
# 2             2          2          92  Laboratory Technician               0
# 3             3          4          56     Research Scientist               8
# 4             2          1          40  Laboratory Technician               2
#
# ...

# %% [markdown]
# ### Excel

# %%
# EXPORT TO EXCEL WITH INDEX TRUE
modify_data.to_excel("Cleaned_Excel.xlsx", index = True)

# %%
# READ EXCEL OUTPUT
pd.read_excel("Cleaned_Excel.xlsx").head()
# Out:
#    Unnamed: 0  Age  Attrition     BusinessTravel  DailyRate  \
# 0           0   41          1      Travel Rarely       1102
# 1           1   49          0  Travel Frequently        279
# 2           2   37          1      Travel Rarely       1373
# 3           3   33          0  Travel Frequently       1392
# 4           4   27          0      Travel Rarely        591
#
#                Department  DistanceHome  Education  HourlyRate  \
# 0                   Sales             1          2          94
# 1  Research & Development             8          1          61
# 2  Research & Development             2          2          92
# 3  Research & Development             3          4          56
# 4  Research & Development             2          1          40
#
#                  JobRole  YearsAtCompany  YearsInCurrentRole  \
# 0        Sales Executive               6                   4
# 1     Research Scientist              10                   7
# ...
