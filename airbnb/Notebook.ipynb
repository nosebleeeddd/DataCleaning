# %%
import pandas as pd

# %%
data = pd.read_csv("Airbnb_Open_Data.csv")

# %%
data.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %% [markdown]
# ### CHECK FOR NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
''' TASKS
Deleting redundant columns.
Renaming the columns.
Dropping duplicates.
Cleaning individual columns.
Remove the NaN values from the dataset
Check for some more Transformations
'''

# %% [markdown]
# # 1. Deleting redundant columns

# %%
data.columns

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']
columns_to_drop = ['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license', 'id']

# %%
len(columns_to_keep)
# Out:
# 19

# %%
len(columns_to_drop)
# Out:
# 7

# %% [markdown]
# ## 1st Method, Filtering Data

# %%
df = data[columns_to_keep]

# %%
#data.shape
df

# %% [markdown]
# ## 2nd Method, Dropping Columns

# %%
data.columns

# %%
# DROP A SINGLE COLUMN
#data.drop(columns = ["license"])

# %%
# Drop columns using filter
data.drop(columns = columns_to_drop, inplace=True)

# %% [markdown]
# data

# %%
''' TASKS
Deleting redundant columns.                 X
Renaming the columns.                            
Dropping duplicates.                      
Cleaning individual columns.                
Remove the NaN values from the dataset      
Check for some more Transformations         
'''

# %% [markdown]
# # 2. Renaming the columns

# %%
data.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
# Change the column NAME to Name
data.rename(columns= {"NAME": "Name"}, inplace=True)

# %%
data.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
# WE HAVE NO MORE COLUMNS TO RENAME
# a solution if u wanted all upper-case
new_columns_names = []
for i in data.columns:
    new_columns_names.append(i.upper())

# %%
# make a copy just in case
new_dataframe_to_modify = data.copy()

# %%
new_dataframe_to_modify.columns = new_columns_names

# %%
new_dataframe_to_modify

# %%
''' TASKS
Deleting redundant columns.                 X
Renaming the columns.                       X     
Dropping duplicates.                        
Cleaning individual columns.                
Remove the NaN values from the dataset      
Check for some more Transformations         
'''

# %% [markdown]
# # 3. Dropping Duplicates

# %%
# Show series duplicates in cells as booleans
data.duplicated()
# Shows total amount of duplicates
data.duplicated().sum()
# Shows both total # true and false
data.duplicated().value_counts()
# Out:
# False    102058
# True        541
# Name: count, dtype: int64

# %%
# Drop and Set changes with inplace or store in var
data.drop_duplicates(inplace=True)

# %%
# Check for 0 duplicates
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
''' TASKS
Deleting redundant columns.                 X
Renaming the columns.                       X     
Dropping duplicates.                        X
Remove the NaN values from the dataset
Cleaning individual columns.                     
Check for some more Transformations         
'''

# %% [markdown]
# # 4. Remove NaN Values

# %%
# Show NaN cell-wise
data.isna()
# Get the amount column-wise
data.isna().sum()
# Out:
# Name                        250
# host id                       0
# host_identity_verified      289
# host name                   404
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# Construction year           214
# price                       247
# service fee                 273
# minimum nights              400
# number of reviews           183
# last review               15832
# dtype: int64

# %%
# Drop a single column
data.drop(columns=["last review"], inplace=True)

# %%
# Drop all NaN Values
data.dropna(inplace = True)

# %%
data.isna().sum()
# Out:
# Name                      0
# host id                   0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# lat                       0
# long                      0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# Construction year         0
# price                     0
# service fee               0
# minimum nights            0
# number of reviews         0
# last review               0
# dtype: int64

# %%
''' TASKS
Deleting redundant columns.                 X
Renaming the columns.                       X     
Dropping duplicates.                        X
Remove the NaN values from the dataset      X
Cleaning individual columns.                     
Check for some more Transformations         
'''

# %% [markdown]
# # 5. Cleaning Individual Columns

# %%
# CHANGE THE SERIES IN THIS COLUMN TO ALL UPPERCASE
data["host_identity_verified"].str.upper()
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 4            VERIFIED
# 5            VERIFIED
# 7         UNCONFIRMED
#              ...
# 102029    UNCONFIRMED
# 102030       VERIFIED
# 102031       VERIFIED
# 102032    UNCONFIRMED
# 102040       VERIFIED
# Name: host_identity_verified, Length: 83969, dtype: object

# %%
# SET THE CHANGES
data["host_identity_verified"] = data["host_identity_verified"].str.upper()

# %%
data
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
# CHANGE TRUE AND FALSE TO BOOLEANS FOR TRAINING MODELS
data["instant_bookable"].apply(lambda x: 1 if x == True else 0)
# Out:
# 0         0
# 1         0
# 4         0
# 5         1
# 7         0
#          ..
# 102029    0
# 102030    1
# 102031    1
# 102032    0
# 102040    1
# Name: instant_bookable, Length: 83969, dtype: int64

# %%
# SET THE CHANGES 
data["instant_bookable"] = data["instant_bookable"].apply(lambda x: 1 if x == True else 0)

# %%
data.head()

# %%
# RESET INDEX FOR PROPER ORDERING
data.reset_index(inplace=True)

# %%
# CHECK TYPE OF COLUMNS SERIES WE CHANGED
type(data["instant_bookable"][15])
# Out:
# numpy.int64

# %%
''' TASKS
Deleting redundant columns.                 X
Renaming the columns.                       X     
Dropping duplicates.                        X
Remove the NaN values from the dataset      X
Cleaning individual columns.                X     
Check for some more Transformations         
'''

# %% [markdown]
# # 6. Check for more Transformations

# %%
data
# Out:
#         index                                              Name      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 83964  102029            Cozy room in a 2B with backyard access   5155155913
# 83965  102030                      An East Williamsburg Delight  71564706996
# 83966  102031                      Cozy bedroom in williamsburg  83101851929
# 83967  102032                            Spacious Room w/ 2 Bed  69037598918
# 83968  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
# FIX THE TYPES FOR COLUMNS
type(data["price"][15])
# Out:
# str

# %%
data["price"].head(3)
# Out:
# 0    $966
# 1    $142
# 2    $204
# Name: price, dtype: object

# %%
# Replace $ with empty string
data["price"].str.replace("$", "")
# Out:
# 0          966
# 1          142
# 2          204
# 3          577
# 4        1,060
#           ...
# 83964      822
# 83965      455
# 83966    1,078
# 83967      103
# 83968      982
# Name: price, Length: 83969, dtype: object

# %%
# Set the changes
data["price"] = data["price"].str.replace("$", "")

# %%
data["price"]
# Out:
# 0          966
# 1          142
# 2          204
# 3          577
# 4        1,060
#           ...
# 83964      822
# 83965      455
# 83966    1,078
# 83967      103
# 83968      982
# Name: price, Length: 83969, dtype: object

# %%
# REMOVE COMMAS IN THE 1000s place
data["price"].str.replace(",","")
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 83964     822
# 83965     455
# 83966    1078
# 83967     103
# 83968     982
# Name: price, Length: 83969, dtype: object

# %%
# Set the changes
data["price"] = data["price"].str.replace(",","")

# %%
data["price"][15]
# Out:
# '370 '

# %%
# FIX SPACE AT END OF PRICE
data["price"] = data["price"].str.replace(" ","")

# %%
data["price"][15]
# Out:
# '370'

# %%
# CHANGE DATA TYPE 
type(data["price"][1])
# Out:
# str

# %%
# Changes column to int datatype
data["price"].astype(int)
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 83964     822
# 83965     455
# 83966    1078
# 83967     103
# 83968     982
# Name: price, Length: 83969, dtype: int64

# %%
# Check the type
#type(data["price"].astype(int)[1])
# Out:
# numpy.int64

# %%
# SET THE CHANGES 
data["price"] = data["price"].astype(int)

# %%
# Check the type for set changes
type(data["price"][1])
# Out:
# numpy.int64

# %% [markdown]
# # EXPORTING DATA

# %% [markdown]
# ## CSV

# %%
# Export to csv
data.to_csv("Cleaned_Data.csv")

# %%
# Read the csv file
pd.read_csv("Cleaned_Data.csv")

# %% [markdown]
# ## Excel

# %%
# Export to excel with index
data.to_excel("Excel_cleaned_data.xlsx", index=False)

# %%
# Read the xlsx file
pd.read_excel("Excel_cleaned_data.xlsx")
# Out:
#         index                                              Name      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 83964  102029            Cozy room in a 2B with backyard access   5155155913
# 83965  102030                      An East Williamsburg Delight  71564706996
# 83966  102031                      Cozy bedroom in williamsburg  83101851929
# 83967  102032                            Spacious Room w/ 2 Bed  69037598918
# 83968  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...
